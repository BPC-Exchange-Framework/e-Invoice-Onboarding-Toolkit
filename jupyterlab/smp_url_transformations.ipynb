# %% [markdown]
# # Important!
# Run the next module first in order to succesfully the rest of the page!

# %%
# !pip install requests

# %%
import requests
import re

protocol = "https"
uri = "smp-api.sc-b2b.us"
standard = "bdxr-smp-2"
services = "services"
service_id = "bdx-docid-qns::urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2"
urns = ('urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kellytestsmp',
        'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kelly2021',
        'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kellysmbtest',
        'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::mnkellyk')
service_group_urls = ('https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellytestsmp',
                      'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akelly2021',
                      'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellysmbtest',
                      'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk')

service_urls = ('https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellytestsmp/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2',
                'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akelly2021/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2',
                'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellysmbtest/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2',
                'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2')

def get_service_group(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)



def get_service(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn + "/" + "services" + "/" + service_id
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("#", "%23", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)





for index, urn in enumerate(urns):
  # print(urns[index])
  # print(get_service_group(urns[index]))
  service_group_url_test = get_service_group(urns[index])
  if service_group_url_test == service_group_urls[index]:
    print("Service group url match!")
    response = requests.get(service_group_url_test)
    print(response.text)
  else: 
    print(f"Service group url {get_service_group(urns[index])} should be {service_group_urls[index]}")
  # print(get_service(urns[index]))
  service_url_test = get_service(urns[index])
  if service_url_test == service_urls[index]:
    print("Service url match!")
    response = requests.get(service_url_test)
    print(response.text)
  else: 
    print(f"Service url {get_service(urns[index])} should be {service_urls[index]}")
# Out:
# Service group url match!
# <?xml version="1.0" encoding="utf-8"?>
# <ServiceGroup xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://docs.oasis-open.org/bdxr/ns/SMP/2/ServiceGroup" xmlns:ext="http://docs.oasis-open.org/bdxr/ns/SMP/2/ExtensionComponents" xmlns:sma="http://docs.oasis-open.org/bdxr/ns/SMP/2/AggregateComponents" xmlns:smb="http://docs.oasis-open.org/bdxr/ns/SMP/2/BasicComponents">
# 	<smb:SMPVersionID>2.0</smb:SMPVersionID>
# 	<smb:ParticipantID schemeID="urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088">kellytestsmp</smb:ParticipantID>
# 	<sma:ServiceReference>
# 		<smb:ID schemeID="bdx-docid-qns">urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2</smb:ID>
# 		<sma:Process>
# 			<smb:ID schemeID="bpcprocess">test:poc:01</smb:ID>
# 		</sma:Process>
# 	</sma:ServiceReference>
# </ServiceGroup>
# Service url match!
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
import requests
import re

protocol = "https"
uri = "smp-api.sc-b2b.us"
standard = "bdxr-smp-2"
services = "services"
service_id = "bdx-docid-qns::urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2"
urns = 'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kellytestsmp'
service_group_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellytestsmp'
service_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellytestsmp/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2'


def get_service_group(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)



def get_service(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn + "/" + "services" + "/" + service_id
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("#", "%23", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)





# print(urns[index])
# print(get_service_group(urns[index]))
service_group_url_test = get_service_group(urns)
if service_group_url_test == service_group_urls:
  print("Service group url match!")
  response = requests.get(service_group_url_test)
  print(response.text)
else: 
  print(f"Service group url {get_service_group(urns[index])} should be {service_group_urls[index]}")
# print(get_service(urns[index]))
service_url_test = get_service(urns)
if service_url_test == service_urls:
  print("Service url match!")
  response = requests.get(service_url_test)
  print(response.text)
else: 
  print(f"Service url {get_service(urns)} should be {service_urls}")






# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice##BPC-UBL-2.2
# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2
# Out:
# Service group url match!
# <?xml version="1.0" encoding="utf-8"?>
# <ServiceGroup xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://docs.oasis-open.org/bdxr/ns/SMP/2/ServiceGroup" xmlns:ext="http://docs.oasis-open.org/bdxr/ns/SMP/2/ExtensionComponents" xmlns:sma="http://docs.oasis-open.org/bdxr/ns/SMP/2/AggregateComponents" xmlns:smb="http://docs.oasis-open.org/bdxr/ns/SMP/2/BasicComponents">
# 	<smb:SMPVersionID>2.0</smb:SMPVersionID>
# 	<smb:ParticipantID schemeID="urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088">kellytestsmp</smb:ParticipantID>
# 	<sma:ServiceReference>
# 		<smb:ID schemeID="bdx-docid-qns">urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2</smb:ID>
# 		<sma:Process>
# 			<smb:ID schemeID="bpcprocess">test:poc:01</smb:ID>
# 		</sma:Process>
# 	</sma:ServiceReference>
# </ServiceGroup>
# Service url match!
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
import requests
import re

protocol = "https"
uri = "smp-api.sc-b2b.us"
standard = "bdxr-smp-2"
services = "services"
service_id = "bdx-docid-qns::urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2"
urns = 'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kellytestsmp'
service_group_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellytestsmp'
service_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellytestsmp/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2'


def get_service_group(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)



def get_service(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn + "/" + "services" + "/" + service_id
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("#", "%23", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)





# print(urns[index])
# print(get_service_group(urns[index]))
service_group_url_test = get_service_group(urns)
if service_group_url_test == service_group_urls:
  print("Service group url match!")
  response = requests.get(service_group_url_test)
  print(response.text)
else: 
  print(f"Service group url {get_service_group(urns[index])} should be {service_group_urls[index]}") 
if service_url_test == service_urls:
  print("Service url match!")
  response = requests.get(service_url_test)
  print(response.text)
else: 
  print(f"Service url {get_service(urns)} should be {service_urls}")






# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice##BPC-UBL-2.2
# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2
# Out:
# Service group url match!
# <?xml version="1.0" encoding="utf-8"?>
# <ServiceGroup xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://docs.oasis-open.org/bdxr/ns/SMP/2/ServiceGroup" xmlns:ext="http://docs.oasis-open.org/bdxr/ns/SMP/2/ExtensionComponents" xmlns:sma="http://docs.oasis-open.org/bdxr/ns/SMP/2/AggregateComponents" xmlns:smb="http://docs.oasis-open.org/bdxr/ns/SMP/2/BasicComponents">
# 	<smb:SMPVersionID>2.0</smb:SMPVersionID>
# 	<smb:ParticipantID schemeID="urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088">kellytestsmp</smb:ParticipantID>
# 	<sma:ServiceReference>
# 		<smb:ID schemeID="bdx-docid-qns">urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2</smb:ID>
# 		<sma:Process>
# 			<smb:ID schemeID="bpcprocess">test:poc:01</smb:ID>
# 		</sma:Process>
# 	</sma:ServiceReference>
# </ServiceGroup>
# Service url match!
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
import requests
import re

protocol = "https"
uri = "smp-api.sc-b2b.us"
standard = "bdxr-smp-2"
services = "services"
service_id = "bdx-docid-qns::urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2"
urns = 'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kelly2021'
service_group_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akelly2021'
service_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akelly2021/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2'


def get_service_group(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)



def get_service(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn + "/" + "services" + "/" + service_id
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("#", "%23", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)





# print(urns[index])
# print(get_service_group(urns[index]))
service_group_url_test = get_service_group(urns)
if service_group_url_test == service_group_urls:
  print("Service group url match!")
  response = requests.get(service_group_url_test)
  print(response.text)
else: 
  print(f"Service group url {get_service_group(urns[index])} should be {service_group_urls[index]}")
# print(get_service(urns[index]))
service_url_test = get_service(urns)
if service_url_test == service_urls:
  print("Service url match!")
  response = requests.get(service_url_test)
  print(response.text)
else: 
  print(f"Service url {get_service(urns)} should be {service_urls}")






# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice##BPC-UBL-2.2
# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2
# Out:
# Service group url match!
# <?xml version="1.0" encoding="utf-8"?>
# <ServiceGroup xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://docs.oasis-open.org/bdxr/ns/SMP/2/ServiceGroup" xmlns:ext="http://docs.oasis-open.org/bdxr/ns/SMP/2/ExtensionComponents" xmlns:sma="http://docs.oasis-open.org/bdxr/ns/SMP/2/AggregateComponents" xmlns:smb="http://docs.oasis-open.org/bdxr/ns/SMP/2/BasicComponents">
# 	<smb:SMPVersionID>2.0</smb:SMPVersionID>
# 	<smb:ParticipantID schemeID="urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088">kelly2021</smb:ParticipantID>
# 	<sma:ServiceReference>
# 		<smb:ID schemeID="bdx-docid-qns">urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2</smb:ID>
# 		<sma:Process>
# 			<smb:ID schemeID="bpcprocess">test:poc:01</smb:ID>
# 		</sma:Process>
# 	</sma:ServiceReference>
# </ServiceGroup>
# Service url match!
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
import requests
import re

protocol = "https"
uri = "smp-api.sc-b2b.us"
standard = "bdxr-smp-2"
services = "services"
service_id = "bdx-docid-qns::urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2"
urns = 'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::kellysmbtest'
service_group_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellysmbtest'
service_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Akellysmbtest/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2'


def get_service_group(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)



def get_service(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn + "/" + "services" + "/" + service_id
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("#", "%23", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)





# print(urns[index])
# print(get_service_group(urns[index]))
service_group_url_test = get_service_group(urns)
if service_group_url_test == service_group_urls:
  print("Service group url match!")
  response = requests.get(service_group_url_test)
  print(response.text)
else: 
  print(f"Service group url {get_service_group(urns[index])} should be {service_group_urls[index]}")
# print(get_service(urns[index]))
service_url_test = get_service(urns)
if service_url_test == service_urls:
  print("Service url match!")
  response = requests.get(service_url_test)
  print(response.text)
else: 
  print(f"Service url {get_service(urns)} should be {service_urls}")






# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice##BPC-UBL-2.2
# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2
# Out:
# Service group url match!
# <?xml version="1.0" encoding="utf-8"?>
# <ServiceGroup xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://docs.oasis-open.org/bdxr/ns/SMP/2/ServiceGroup" xmlns:ext="http://docs.oasis-open.org/bdxr/ns/SMP/2/ExtensionComponents" xmlns:sma="http://docs.oasis-open.org/bdxr/ns/SMP/2/AggregateComponents" xmlns:smb="http://docs.oasis-open.org/bdxr/ns/SMP/2/BasicComponents">
# 	<smb:SMPVersionID>2.0</smb:SMPVersionID>
# 	<smb:ParticipantID schemeID="urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088">kellysmbtest</smb:ParticipantID>
# 	<sma:ServiceReference>
# 		<smb:ID schemeID="bdx-docid-qns">urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2</smb:ID>
# 		<sma:Process>
# 			<smb:ID schemeID="bpcprocess">test:poc:01</smb:ID>
# 		</sma:Process>
# 	</sma:ServiceReference>
# </ServiceGroup>
# Service url match!
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
import requests
import re

protocol = "https"
uri = "smp-api.sc-b2b.us"
standard = "bdxr-smp-2"
services = "services"
service_id = "bdx-docid-qns::urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2"
urns = 'urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088::mnkellyk'
service_group_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk'
service_urls = 'https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2'


def get_service_group(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)



def get_service(urn):
  request_url = protocol + "://" + uri + "/" + standard + "/" + urn + "/" + "services" + "/" + service_id
  request_url = re.sub(":", "%3A", request_url)
  request_url = re.sub("#", "%23", request_url)
  request_url = re.sub("https%3A", "https:", request_url)
  return(request_url)





# print(urns[index])
# print(get_service_group(urns[index]))
service_group_url_test = get_service_group(urns)
if service_group_url_test == service_group_urls:
  print("Service group url match!")
  response = requests.get(service_group_url_test)
  print(response.text)
else: 
  print(f"Service group url {get_service_group(urns[index])} should be {service_group_urls[index]}")
# print(get_service(urns[index]))
service_url_test = get_service(urns)
if service_url_test == service_urls:
  print("Service url match!")
  response = requests.get(service_url_test)
  print(response.text)
else: 
  print(f"Service url {get_service(urns)} should be {service_urls}")






# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice##BPC-UBL-2.2
# https://smp-api.sc-b2b.us/bdxr-smp-2/urn%3Aoasis%3Anames%3Atc%3Aebcore%3Apartyid-type%3Aiso6523%3A0088%3A%3Amnkellyk/services/bdx-docid-qns%3A%3Aurn%3Aoasis%3Anames%3Aspecification%3Aubl%3Aschema%3Axsd%3AInvoice-1%3A%3AInvoice%23%23BPC-UBL-2.2
# Out:
# Service group url match!
# <?xml version="1.0" encoding="utf-8"?>
# <ServiceGroup xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://docs.oasis-open.org/bdxr/ns/SMP/2/ServiceGroup" xmlns:ext="http://docs.oasis-open.org/bdxr/ns/SMP/2/ExtensionComponents" xmlns:sma="http://docs.oasis-open.org/bdxr/ns/SMP/2/AggregateComponents" xmlns:smb="http://docs.oasis-open.org/bdxr/ns/SMP/2/BasicComponents">
# 	<smb:SMPVersionID>2.0</smb:SMPVersionID>
# 	<smb:ParticipantID schemeID="urn:oasis:names:tc:ebcore:partyid-type:iso6523:0088">mnkellyk</smb:ParticipantID>
# 	<sma:ServiceReference>
# 		<smb:ID schemeID="bdx-docid-qns">urn:oasis:names:specification:ubl:schema:xsd:Invoice-1::Invoice##BPC-UBL-2.2</smb:ID>
# 		<sma:Process>
# 			<smb:ID schemeID="bpcprocess">test:poc:01</smb:ID>
# 		</sma:Process>
# 	</sma:ServiceReference>
# </ServiceGroup>
# Service url match!
# <?xml version="1.0" encoding="utf-8"?>
# ...
